# %%
PI = 3.14
print("Es el primer bloque del proyecto")
# Out:
# Es el primer bloque del proyecto

# %%
print("Es el segundo bloque del proyecto")
print(PI)
# Out:
# Es el segundo bloque del proyecto
# 3.14

# %% [markdown]
# # PUNTO 5
# Al seleccionar la opccion "Restart", aparecio un cartel que decia "Esta seguro de querer reiniciar el kernel actual? todas las variables se perderan." y al darle "Restart", de nuevo, se reinicio el kernel

# %% [markdown]
# # PUNTO 6
# Cuando oprimimos "Restart" no sucedio nada, solamente nos aparecio un cartel que decia que "las variables se perderian". Se reinicia el nucleo.
# Al oprimir "Clear and Output" Reinicia el kernel y borra todos los resultados de salida.
# Al oprimir "Interrupt" se interrumpe la ejecucion del codigo.

# %% [markdown]
# # PUNTO 7
# La funcion que cumple ln["Numero"] es indicar que es un bloque de codigo, y el numero indica el orden en que se ejecutan.

# %% [markdown]
# # Universidad Autónoma de Entre Ríos
# ## Facultad de Ciencia y Tecnología
# ### Sede Concepción del Uruguay
# Licenciatura en Sistema de Información:
# - Primer año
# - Segundo año
# - **Tercer** año
# - Cuarto año
# - Quinto año

# %% [markdown]
# ![Imagen](https://concepto.de/wp-content/uploads/2015/03/software-1-e1550080097569.jpg)

# %% [markdown]
# ![software-1.jpg](attachment:software-1.jpg)

# %% [markdown]
# #Punto11
# Seleccionando edit, luego move cell up o move cell down se puede cambiar de lugar las celdas. Para dividirlas se usa el split cell, y para unir con una celda de abajo o de arriba se usa merge cell above o merge cell below.
